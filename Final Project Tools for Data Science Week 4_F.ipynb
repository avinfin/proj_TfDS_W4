# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Name:Avi Nanous** <br>
# Product Manager, Home Chef

# %% [markdown]
# *I am interested in data science because it encorporate important knowledge and foundations for Machine Learning & AI*

# %% [markdown]
# ### The following code computes a simple arithmetic function

# %%
2+2
# Out:
# 4

# %% [markdown]
# ***
# **bulleted list**
# - first item
# - second item
# - third item
#
# **numbered list**
# 1. first item
# 2. second item
# 3. third item
#
# __[IBM's Site Link](http://www.ibm.com)__
#
# #### My cusine sample image
# ![20180907_151005__.jpg](attachment:20180907_151005__.jpg)
